# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Challenge 1

# read in the data:
import pandas as pd
df_1 = pd.read_csv('data files/turnstile_190706.txt')
df_2 = pd.read_csv('data files/turnstile_190713.txt')
df_3 = pd.read_csv('data files/turnstile_190720.txt')
df_4 = pd.read_csv('data files/turnstile_190727.txt')
df_5 = pd.read_csv('data files/turnstile_190803.txt')
df_6 = pd.read_csv('data files/turnstile_190810.txt')
df_7 = pd.read_csv('data files/turnstile_190817.txt')
df_8 = pd.read_csv('data files/turnstile_190824.txt')
df_9 = pd.read_csv('data files/turnstile_190831.txt')

#concatenate
df_combined = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9])

# %%
# Column name 'EXITS' needs to be formatted to remove extra spaces
print(df_combined.columns)
df_combined.rename(columns={df_combined.columns[10]:'EXITS'}, inplace=True)
print(df_combined.columns)
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
# Challenge 2

# What data type did pandas assign values in columns 'Date' and 'Time'?
print(type(df_combined.DATE.iloc[0]), type(df_combined.TIME.iloc[0]))

# Combine 'Date' and 'Time' columns and format into a datetime object
df_combined['DATETIME'] = pd.to_datetime(df_combined['DATE']+ ' ' + df_combined['TIME'])
#df_combined.drop(columns=['DATE','TIME'], inplace=True, axis=1)
print(df_combined.head())
# Out:
# <class 'str'> <class 'str'>
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/29/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/29/2019  08:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/29/2019  12:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/29/2019  16:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/29/2019  20:00:00
#
#       DESC  ENTRIES    EXITS            DATETIME
# 0  REGULAR  7116734  2410183 2019-06-29 00:00:00
# 1  REGULAR  7116770  2410218 2019-06-29 08:00:00
# 2  REGULAR  7116856  2410288 2019-06-29 12:00:00
# 3  REGULAR  7117076  2410346 2019-06-29 16:00:00
# 4  REGULAR  7117340  2410387 2019-06-29 20:00:00

# %%
# group by turnstile and date, take the first value for each day
turnstiles_daily = (df_combined
                        .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE"],as_index=False)
                        .first())

# %%
turnstiles_daily[["PREV_DATE", "PREV_ENTRIES", "PREV_EXITS"]] = (turnstiles_daily
                                                       .groupby(["C/A", "UNIT", "SCP", "STATION"])["DATE", "ENTRIES", "EXITS"]
                                                       .apply(lambda grp: grp.shift(1)))
# Out:
# <ipython-input-6-a52010f25ff0>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   turnstiles_daily[["PREV_DATE", "PREV_ENTRIES", "PREV_EXITS"]] = (turnstiles_daily

# %%
# remove NaN
turnstiles_daily.dropna(subset=['PREV_DATE'],axis=0,inplace=True)

# %%
turnstiles_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE LINENAME DIVISION      TIME  \
# 1  A002  R051  02-00-00   59 ST  06/30/2019  NQR456W      BMT  00:00:00
# 2  A002  R051  02-00-00   59 ST  07/01/2019  NQR456W      BMT  00:00:00
# 3  A002  R051  02-00-00   59 ST  07/02/2019  NQR456W      BMT  00:00:00
# 4  A002  R051  02-00-00   59 ST  07/03/2019  NQR456W      BMT  00:00:00
# 5  A002  R051  02-00-00   59 ST  07/04/2019  NQR456W      BMT  00:00:00
#
#       DESC  ENTRIES    EXITS   DATETIME   PREV_DATE  PREV_ENTRIES  PREV_EXITS
# 1  REGULAR  7117480  2410406 2019-06-30  06/29/2019     7116734.0   2410183.0
# 2  REGULAR  7118119  2410590 2019-07-01  06/30/2019     7117480.0   2410406.0
# 3  REGULAR  7119610  2410993 2019-07-02  07/01/2019     7118119.0   2410590.0
# 4  REGULAR  7121181  2411468 2019-07-03  07/02/2019     7119610.0   2410993.0
# 5  REGULAR  7122652  2411887 2019-07-04  07/03/2019     7121181.0   2411468.0

# %%
# check which stations have turnstiles with fewer ENTRIES than the previous day
(turnstiles_daily[turnstiles_daily["ENTRIES"] < turnstiles_daily["PREV_ENTRIES"]]
    .groupby(["C/A", "UNIT", "SCP", "STATION"])
    .size())
# Out:
# C/A   UNIT  SCP       STATION
# A002  R051  02-06-00  59 ST               1
# A007  R079  01-05-01  5 AV/59 ST          1
# A011  R080  01-03-00  57 ST-7 AV         10
# A025  R023  01-03-01  34 ST-HERALD SQ    62
# A035  R170  00-00-01  14 ST-UNION SQ      1
#                                          ..
# R622  R123  00-00-00  FRANKLIN AV        62
# R629  R065  00-00-01  ROCKAWAY AV         1
# R645  R110  00-03-02  FLATBUSH AV-B.C     2
# R646  R110  01-00-01  FLATBUSH AV-B.C    62
# R730  R431  00-00-04  EASTCHSTER/DYRE    58
# Length: 193, dtype: int64

# %%
# check which stations have turnstiles with fewer EXITS than the previous day
(turnstiles_daily[turnstiles_daily["EXITS"] < turnstiles_daily["PREV_EXITS"]]
    .groupby(["C/A", "UNIT", "SCP", "STATION"])
    .size())
# Out:
# C/A   UNIT  SCP       STATION
# A002  R051  02-06-00  59 ST               1
# A007  R079  01-05-01  5 AV/59 ST          1
# A011  R080  01-03-00  57 ST-7 AV         13
# A035  R170  00-00-01  14 ST-UNION SQ      1
# A043  R462  00-03-03  CANAL ST            1
#                                          ..
# R621  R060  00-03-01  EASTN PKWY-MUSM     1
# R622  R123  00-00-00  FRANKLIN AV        62
# R629  R065  00-00-01  ROCKAWAY AV         1
# R645  R110  00-03-02  FLATBUSH AV-B.C     2
# R646  R110  01-00-01  FLATBUSH AV-B.C    62
# Length: 186, dtype: int64

# %%
# If the counter is reversed, make negative values positive
# If difference between days is >= 1 million, set daily ENTRIES to min value between ENTRIES and prev_ENTRIES
def get_daily_counts(row, max_counter):
    counter = row["ENTRIES"] - row["PREV_ENTRIES"]
    if counter < 0:
        # Maybe counter is reversed?
        counter = -counter
    if counter > max_counter:
        # Maybe counter was reset to 0? 
        print(row["ENTRIES"], row["PREV_ENTRIES"])
        counter = 0
    if counter > max_counter:
        # Check it again to make sure we're not still giving a counter that's too big
        return 0
    return counter

# If counter is > 1Million, then the counter might have been reset.  
# Just set it to zero as different counters have different cycle limits
# It'd probably be a good idea to use a number even significantly smaller than 1 million as the limit!
turnstiles_daily["DAILY_ENTRIES"] = turnstiles_daily.apply(get_daily_counts, axis=1, max_counter=1000000)
# Out:
# 824 3557655.0
# 458818 12876202.0
# 459073 68448066.0
# 2000091722 6897017.0
# 11 2029641496.0
# 7 2997591.0
# 5327464 4320256.0
# 4320257 2920966.0
# 319 5420925.0
# 721090 5343128.0
# 262 3407291.0
# 26 1652502.0
# 422 17135909.0
# 22 2129136933.0
# 21 13593836.0
# 27 7808518.0
# 304 4587522.0
# 1962917508 9137626.0
# 393224 117441229.0
# 23 2130567.0
# 352361657 1409610.0
# 80 3260287.0
# 134 3376441.0
# 351 3839369.0
# 1487 4721413.0
# 983271 3670866.0
# 171 1788082.0
# 1325342695 11664583.0
# 105 7542484.0
# 458765 6627959.0
# 354 5366386.0
# 524295 2338090.0
# 1359886 4065.0
# 70 5631392.0
# 871 2543403.0
# 892 1975856.0
# 37 1514083866.0
# 34 12122524.0
# 25 1229078732.0
# 1572864 2139.0
# 1233 4018083.0
# 214 9789350.0
# 7 1370664.0
# 2162762 33622258.0
# 592416496 389431.0
# 6 5705107.0
# 933 1285128.0
# 1792 6138105.0
# 1543 10213611.0
# 18806 654821321.0
# 163997279 972453993.0
# 437 36992180.0
# 78260066 1442544807.0
# 1862330382 7277226.0
# 33754095 50516744.0
# 50474287 33772995.0
# 1594421086 140471461.0
# 930 1108422349.0
# 181 18340503.0
# 109924748 1928952716.0
# 98096722 670717696.0
# 2046764758 8810196.0
# 1124011327 12446364.0
# 110 6409107.0

# %%
# If the counter is reversed, make negative values positive
# If difference between days is >= 1 million, set daily EXITS to min value between EXITS and prev_EXITS
def get_daily_counts(row, max_counter):
    counter = row["EXITS"] - row["PREV_EXITS"]
    if counter < 0:
        # Maybe counter is reversed?
        counter = -counter
    if counter > max_counter:
        # Maybe counter was reset to 0? 
        print(row["EXITS"], row["PREV_EXITS"])
        counter = 0
    if counter > max_counter:
        # Check it again to make sure we're not still giving a counter that's too big
        return 0
    return counter

# If counter is > 1Million, then the counter might have been reset.  
# Just set it to zero as different counters have different cycle limits
# It'd probably be a good idea to use a number even significantly smaller than 1 million as the limit!
turnstiles_daily["DAILY_EXITS"] = turnstiles_daily.apply(get_daily_counts, axis=1, max_counter=1000000)
# Out:
# 1314 1109237.0
# 526 1833014.0
# 43 2255995.0
# 166 16906899.0
# 0 1045674.0
# 1850345261 8702864.0
# 3 702629110.0
# 0 4745858.0
# 3430095 8440580.0
# 4745860 2455688.0
# 8440589 1962487.0
# 219 10787335.0
# 327 6368810.0
# 451 2579110.0
# 205 10179613.0
# 16 1155490186.0
# 14 15837624.0
# 15 4262163.0
# 317 3351226.0
# 318790205 1305671.0
# 604040484 2397891.0
# 435 12613231.0
# 1137 10021370.0
# 165 1692611.0
# 687875257 2749154.0
# 95 3163183.0
# 1908 13790712.0
# 910 3642394.0
# 144 3425513.0
# 712 1437147.0
# 120 12292134.0
# 379 2592663.0
# 17 908660197.0
# 14 7483993.0
# 15 1921803310.0
# 671 1919118.0
# 1112 12197572.0
# 453 219039396.0
# 211 1435950.0
# 886336027 202295.0
# 2467 2526158.0
# 3704 13303075.0
# 3331 616256155.0
# 65993790 301732246.0
# 423 505935940.0
# 20003723 822184273.0
# 1409339334 5560810.0
# 419673663 51974602.0
# 126 167971300.0
# 192 5707560.0
# 114871396 670631915.0
# 18771850 503395116.0
# 1426010267 11255249.0
# 1979716419 7792331.0
# 2414 2795721.0
# 74 6328249.0

# %%
#clean entries
mask_entries = (turnstiles_daily["DAILY_ENTRIES"] != 0)
turnstiles_daily_entries_clean = turnstiles_daily[mask_entries]

# %%
#clean exits from the cleaned entries df
mask_exits = (turnstiles_daily_entries_clean["DAILY_EXITS"] != 0)
turnstiles_daily_exits_clean = turnstiles_daily_entries_clean[mask_exits]

# %%
#rename final cleaned entries and exits df for easier reference
turnstiles_daily_cleaned = turnstiles_daily_exits_clean

# %%
turnstiles_daily_cleaned.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE LINENAME DIVISION      TIME  \
# 1  A002  R051  02-00-00   59 ST  06/30/2019  NQR456W      BMT  00:00:00
# 2  A002  R051  02-00-00   59 ST  07/01/2019  NQR456W      BMT  00:00:00
# 3  A002  R051  02-00-00   59 ST  07/02/2019  NQR456W      BMT  00:00:00
# 4  A002  R051  02-00-00   59 ST  07/03/2019  NQR456W      BMT  00:00:00
# 5  A002  R051  02-00-00   59 ST  07/04/2019  NQR456W      BMT  00:00:00
#
#       DESC  ENTRIES    EXITS   DATETIME   PREV_DATE  PREV_ENTRIES  PREV_EXITS  \
# 1  REGULAR  7117480  2410406 2019-06-30  06/29/2019     7116734.0   2410183.0
# 2  REGULAR  7118119  2410590 2019-07-01  06/30/2019     7117480.0   2410406.0
# 3  REGULAR  7119610  2410993 2019-07-02  07/01/2019     7118119.0   2410590.0
# 4  REGULAR  7121181  2411468 2019-07-03  07/02/2019     7119610.0   2410993.0
# 5  REGULAR  7122652  2411887 2019-07-04  07/03/2019     7121181.0   2411468.0
#
#    DAILY_ENTRIES  DAILY_EXITS
# 1          746.0        223.0
# 2          639.0        184.0
# 3         1491.0        403.0
# 4         1571.0        475.0
# 5         1471.0        419.0

# %%
turnstiles_daily_cleaned['DAILY_TOTALS'] = turnstiles_daily_cleaned.apply(lambda row: row.DAILY_ENTRIES + row.DAILY_EXITS, axis=1)
# Out:
# <ipython-input-18-0b594facd523>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   turnstiles_daily_cleaned['DAILY_TOTALS'] = turnstiles_daily_cleaned.apply(lambda row: row.DAILY_ENTRIES + row.DAILY_EXITS, axis=1)

# %%
turnstiles_daily_cleaned.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE LINENAME DIVISION      TIME  \
# 1  A002  R051  02-00-00   59 ST  06/30/2019  NQR456W      BMT  00:00:00
# 2  A002  R051  02-00-00   59 ST  07/01/2019  NQR456W      BMT  00:00:00
# 3  A002  R051  02-00-00   59 ST  07/02/2019  NQR456W      BMT  00:00:00
# 4  A002  R051  02-00-00   59 ST  07/03/2019  NQR456W      BMT  00:00:00
# 5  A002  R051  02-00-00   59 ST  07/04/2019  NQR456W      BMT  00:00:00
#
#       DESC  ENTRIES    EXITS   DATETIME   PREV_DATE  PREV_ENTRIES  PREV_EXITS  \
# 1  REGULAR  7117480  2410406 2019-06-30  06/29/2019     7116734.0   2410183.0
# 2  REGULAR  7118119  2410590 2019-07-01  06/30/2019     7117480.0   2410406.0
# 3  REGULAR  7119610  2410993 2019-07-02  07/01/2019     7118119.0   2410590.0
# 4  REGULAR  7121181  2411468 2019-07-03  07/02/2019     7119610.0   2410993.0
# 5  REGULAR  7122652  2411887 2019-07-04  07/03/2019     7121181.0   2411468.0
#
#    DAILY_ENTRIES  DAILY_EXITS  DAILY_TOTALS
# 1          746.0        223.0         969.0
# 2          639.0        184.0         823.0
# 3         1491.0        403.0        1894.0
# 4         1571.0        475.0        2046.0
# 5         1471.0        419.0        1890.0

# %%
# First get sum of all turnstiles at each station for each day
# ...then take the average across all days
# ...this shows the station that has the highest daily average
busiest_stations = turnstiles_daily_cleaned.groupby(['STATION','LINENAME','DATE']).sum()\
.groupby(['STATION','LINENAME']).mean().sort_values('DAILY_TOTALS', ascending=False).reset_index()
busiest_stations
# Out:
#              STATION      LINENAME       ENTRIES         EXITS  PREV_ENTRIES  \
# 0    GRD CNTRL-42 ST         4567S  2.279539e+09  3.139953e+09  2.279426e+09
# 1    34 ST-HERALD SQ      BDFMNQRW  4.064813e+09  5.221403e+09  4.064716e+09
# 2    42 ST-PORT AUTH  ACENQRS1237W  7.310532e+09  6.144562e+09  7.310474e+09
# 3     34 ST-PENN STA           ACE  1.428481e+09  1.575457e+09  1.428409e+09
# 4     TIMES SQ-42 ST  1237ACENQRSW  5.657908e+09  3.045489e+09  5.657855e+09
# ..               ...           ...           ...           ...           ...
# 473         BAY PKWY             F  5.799939e+06  2.627299e+06  5.799005e+06
# 474     BEACH 105 ST            AS  1.470087e+06  1.960951e+06  1.469625e+06
# 475    BROAD CHANNEL            AS  1.400036e+06  2.107390e+05  1.399767e+06
# 476    ORCHARD BEACH             6  4.513993e+05  2.832629e+04  4.512234e+05
# 477    TOMPKINSVILLE             1  6.205400e+05  4.301000e+03  6.203730e+05
#
#        PREV_EXITS  DAILY_ENTRIES    DAILY_EXITS   DAILY_TOTALS
# 0    3.139863e+09  176672.532258  125305.741935  301978.274194
# 1    5.221301e+09  106574.225806  101718.435484  208292.661290
# 2    6.144504e+09   78855.483871   63531.241935  142386.725806
# 3    1.575393e+09   71198.387097   64692.274194  135890.661290
# 4    3.045433e+09   57092.693548   56123.387097  113216.080645
# ..            ...            ...            ...            ...
# 473  2.626988e+06     934.000000     310.483871    1244.483871
# 474  1.960515e+06     462.032258     435.548387     897.580645
# 475  2.106515e+05     269.435484      87.548387     356.983871
# 476  2.829347e+04     175.868421      32.815789     208.684211
# 477  4.300000e+03     167.000000       1.000000     168.000000
#
# [478 rows x 9 columns]

# %%
top_stations_list = busiest_stations[0:20]
top_stations_list
# Out:
#             STATION      LINENAME       ENTRIES         EXITS  PREV_ENTRIES  \
# 0   GRD CNTRL-42 ST         4567S  2.279539e+09  3.139953e+09  2.279426e+09
# 1   34 ST-HERALD SQ      BDFMNQRW  4.064813e+09  5.221403e+09  4.064716e+09
# 2   42 ST-PORT AUTH  ACENQRS1237W  7.310532e+09  6.144562e+09  7.310474e+09
# 3    34 ST-PENN STA           ACE  1.428481e+09  1.575457e+09  1.428409e+09
# 4    TIMES SQ-42 ST  1237ACENQRSW  5.657908e+09  3.045489e+09  5.657855e+09
# 5    14 ST-UNION SQ      LNQR456W  3.344725e+08  1.688777e+08  3.344160e+08
# 6         FULTON ST      2345ACJZ  9.141935e+08  8.283449e+08  9.141445e+08
# 7    47-50 STS ROCK          BDFM  2.129552e+09  2.224244e+09  2.129503e+09
# 8      PATH NEW WTC             1  2.019852e+06  1.779122e+06  1.981994e+06
# 9     FLUSHING-MAIN             7  2.059676e+08  1.960639e+08  2.059177e+08
# 10   59 ST COLUMBUS         ABCD1  2.132950e+09  1.716014e+09  2.132904e+09
# 11            72 ST           123  2.048703e+09  3.065535e+09  2.048691e+09
# 12         CANAL ST       JNQRZ6W  3.068268e+09  4.815890e+09  3.068228e+09
# 13  JKSN HT-ROOSVLT         EFMR7  1.090846e+08  1.018884e+08  1.090403e+08
# 14   34 ST-PENN STA        123ACE  1.866236e+09  2.250732e+09  1.866197e+09
# 15  42 ST-BRYANT PK         BDFM7  1.946849e+09  1.415395e+09  1.946815e+09
# 16   W 4 ST-WASH SQ       ABCDEFM  1.311676e+08  1.188512e+08  1.311302e+08
# 17            86 ST           456  1.557465e+09  2.285601e+09  1.557432e+09
# 18            59 ST       456NQRW  1.913644e+09  1.495175e+09  1.913612e+09
# 19  LEXINGTON AV/53           EM6  2.646280e+09  3.374716e+09  2.646251e+09
#
#       PREV_EXITS  DAILY_ENTRIES    DAILY_EXITS   DAILY_TOTALS
# 0   3.139863e+09  176672.532258  125305.741935  301978.274194
# 1   5.221301e+09  106574.225806  101718.435484  208292.661290
# 2   6.144504e+09   78855.483871   63531.241935  142386.725806
# 3   1.575393e+09   71198.387097   64692.274194  135890.661290
# 4   3.045433e+09   57092.693548   56123.387097  113216.080645
# 5   1.688265e+08   56520.612903   51209.645161  107730.258065
# 6   8.282951e+08   51114.854839   50827.774194  101942.629032
# 7   2.224194e+09   48529.725806   50205.177419   98734.903226
# 8   1.744729e+06   50908.548387   45390.467742   96299.016129
# 9   1.960194e+08   49922.370968   44522.048387   94444.419355
# 10  1.715975e+09   47495.967742   40724.693548   88220.661290
# 11  3.065523e+09   42333.709677   41898.370968   84232.080645
# 12  4.815858e+09   47418.870968   31648.532258   79067.403226
# 13  1.018540e+08   44299.229508   34393.590164   78692.819672
# 14  2.250699e+09   41136.327869   35885.901639   77022.229508
# 15  1.415359e+09   39026.241935   37195.306452   76221.548387
# 16  1.188162e+08   37478.919355   35023.483871   72502.403226
# 17  2.285567e+09   34854.870968   36183.241935   71038.112903
# 18  1.495143e+09   33414.516129   34982.806452   68397.322581
# 19  3.374683e+09   33080.822581   33536.387097   66617.209677

# %%
#renamming stations to reflect their crossstreets 
#many of them share names with stations on different lines.
graph_labels = ['GRD CNTRL-42 ST', 
                '34 ST-HERALD SQ', 
                '42 ST-PORT AUTH', 
                '34 ST-PENN (8AV)',
                'TIMES SQ-42 ST',
                '14 ST-UNION SQ',
                'FULTON ST',
                '47-50 STS ROCK',
                'PATH NEW WTC',
                'FLUSHING-MAIN',
                '59 ST COLUMBUS',
                '72 ST (7AV)',
                'CANAL ST (BDWY)',
                'JKSN HT-ROOSVLT',
                '34 ST-PENN (7AV)',
                '42 ST-BRYANT PK',
                'W 4 ST-WASH SQ',
                '86 ST (LEX)',
                '59 ST (LEX)',
                'LEXINGTON AV/53']

# %%
top_stations_list['STATION_RENAMED'] = graph_labels
# Out:
# <ipython-input-30-17f762241b88>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_stations_list['STATION_RENAMED'] = graph_labels

# %%
top_stations_list.head()
# Out:
#            STATION      LINENAME       ENTRIES         EXITS  PREV_ENTRIES  \
# 0  GRD CNTRL-42 ST         4567S  2.279539e+09  3.139953e+09  2.279426e+09
# 1  34 ST-HERALD SQ      BDFMNQRW  4.064813e+09  5.221403e+09  4.064716e+09
# 2  42 ST-PORT AUTH  ACENQRS1237W  7.310532e+09  6.144562e+09  7.310474e+09
# 3   34 ST-PENN STA           ACE  1.428481e+09  1.575457e+09  1.428409e+09
# 4   TIMES SQ-42 ST  1237ACENQRSW  5.657908e+09  3.045489e+09  5.657855e+09
#
#      PREV_EXITS  DAILY_ENTRIES    DAILY_EXITS   DAILY_TOTALS   STATION_RENAMED
# 0  3.139863e+09  176672.532258  125305.741935  301978.274194   GRD CNTRL-42 ST
# 1  5.221301e+09  106574.225806  101718.435484  208292.661290   34 ST-HERALD SQ
# 2  6.144504e+09   78855.483871   63531.241935  142386.725806   42 ST-PORT AUTH
# 3  1.575393e+09   71198.387097   64692.274194  135890.661290  34 ST-PENN (8AV)
# 4  3.045433e+09   57092.693548   56123.387097  113216.080645    TIMES SQ-42 ST

# %%
sns.set(style="white", font = 'verdana')
        #''font.family':'serif', 'font.serif':'Times New Roman'})
#sns.set_style('whitegrid', {'font.family':'serif', 'font.serif':'Times New Roman'})

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))

# Load the data set and sort it from top daily totals to bottom.
crashes = top_stations_list.sort_values("DAILY_TOTALS", ascending=False)

#sns.set_color_codes("pastel")
sns.barplot(x="DAILY_TOTALS", y="STATION_RENAMED", data=top_stations_list,
            label="Total", palette="Blues_r");

# Add a legend and informative axis label

ax.set(ylabel="", xlabel="")
sns.despine(left=True, bottom=True, right = True)

plt.savefig('Top 20 Stations- low res.png')
plt.savefig('Top 20 Stations- pretty.png', dpi=300)
